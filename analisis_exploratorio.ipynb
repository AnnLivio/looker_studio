# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnLivio/runkeeper_data_analysis/blob/main/analisis_exploratorio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Don't stop me now 🏃
# En esta parte analizaremos y responderemos preguntas sobre mi primer año que va desde: Julio de 2023 a Junio de 2024.

# %%
# Import libraries
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore") # do not distube mode

# %%
# Load data
path = '/content/drive/MyDrive/Data Analysis/01_runkeeper_data/running_202307202406.csv'
df = pd.read_csv(path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       215 non-null    object
#  1   Type       215 non-null    object
#  2   Distance   215 non-null    float64
#  3   Duration   215 non-null    float64
#  4   Avg_speed  215 non-null    float64
#  5   Climb      215 non-null    int64
#  6   Steps      214 non-null    float64
#  7   Month      215 non-null    int64
#  8   WeekDay    215 non-null    int64
#  9   Intensity  215 non-null    int64
#  10  Weekend    215 non-null    int64
# dtypes: float64(4), int64(5), object(2)
# memory usage: 18.6+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d %H:%M:%S')

# Drop unnecessary columns
df.drop(columns=['Intensity','Weekend'], inplace=True)

# %%
df.head()
# Out:
#                  Date     Type  Distance  Duration  Avg_speed  Climb   Steps  \
# 0 2024-06-22 19:31:10  Running      6.10     38.27       9.57     60  6434.0
# 1 2024-05-31 10:06:04  Running      7.20     41.80      10.33     47  7365.0
# 2 2024-05-29 10:55:14  Running      9.22     53.63      10.31     67  9077.0
# 3 2024-05-28 19:18:04  Running      6.37     35.95      10.63     33  6305.0
# 4 2024-05-27 19:02:08  Running      7.12     39.87      10.72     70  6681.0
#
#    Month  WeekDay
# 0      6        5
# 1      5        4
# 2      5        2
# 3      5        1
# 4      5        0

# %%
df.describe()
# Out:
#                                 Date    Distance    Duration   Avg_speed  \
# count                            215  215.000000  215.000000  215.000000
# mean   2023-12-21 03:03:30.288371968    7.398000   43.498093   10.244326
# min              2023-07-02 09:13:52    5.070000   31.200000    7.570000
# 25%       2023-09-25 06:42:28.500000    6.120000   35.965000   10.040000
# 50%              2023-12-16 10:52:17    6.580000   39.780000   10.540000
# 75%       2024-03-20 04:45:14.500000    8.155000   47.065000   10.795000
# max              2024-06-22 19:31:10   15.910000   95.080000   11.550000
# std                              NaN    1.748853   10.582849    0.817548
#
#             Climb         Steps       Month     WeekDay
# count  215.000000    214.000000  215.000000  215.000000
# mean    62.386047   7343.257009    6.293023    2.781395
# min     23.000000   2382.000000    1.000000    0.000000
# 25%     46.000000   6232.750000    3.000000    1.000000
# ...

# %% [markdown]
# ## Answering questions

# %% [markdown]
# ### 1. Top 3 carreras más largas

# %%
df.sort_values('Distance', ascending=False).head(3)
# Out:
#                    Date     Type  Distance  Duration  Avg_speed  Climb  \
# 85  2024-02-05 15:50:36  Running     15.91     95.08      10.04    167
# 167 2023-09-11 08:57:28  Running     14.08     92.12       9.17    155
# 91  2024-01-28 15:45:15  Running     12.25     69.52      10.58    121
#
#        Steps  Month  WeekDay
# 85   16729.0      2        0
# 167  16113.0      9        0
# 91   12079.0      1        6

# %% [markdown]
# ### 2. Top 3 carreras más rápidas

# %%
df.sort_values('Avg_speed', ascending=False).head(5)
# Out:
#                   Date     Type  Distance  Duration  Avg_speed  Climb   Steps  \
# 36 2024-04-12 16:27:51  Running      6.37     33.08      11.55     27  4964.0
# 38 2024-04-09 15:16:02  Running      6.25     32.85      11.41     24  4863.0
# 37 2024-04-11 10:58:38  Running      6.25     33.07      11.35     25  5979.0
# 39 2024-04-08 11:25:27  Running      6.12     32.38      11.34     26  4754.0
# 87 2024-02-02 15:43:09  Running      6.36     33.75      11.30     55  5937.0
#
#     Month  WeekDay
# 36      4        4
# 38      4        1
# 37      4        3
# 39      4        0
# 87      2        4

# %% [markdown]
# ### 3. Top 5 carreras con mayor desnivel positivo

# %%
df.sort_values('Climb', ascending=False).head()
# Out:
#                    Date     Type  Distance  Duration  Avg_speed  Climb  \
# 162 2023-09-22 10:06:31  Running      8.07     55.08       8.79    220
# 105 2023-12-24 09:46:08  Running     10.08     61.58       9.82    207
# 104 2024-01-01 10:23:07  Running     10.69     63.37      10.12    196
# 163 2023-09-21 09:43:28  Running      7.05     49.42       8.56    178
# 85  2024-02-05 15:50:36  Running     15.91     95.08      10.04    167
#
#        Steps  Month  WeekDay
# 162   9486.0      9        4
# 105   6798.0     12        6
# 104  11372.0      1        0
# 163   8326.0      9        3
# 85   16729.0      2        0

# %% [markdown]
# ### 4. Total kms corridos en el primer año

# %%
# Total Distance in kms
df.Distance.sum().round(2)
# Out:
# 1590.57

# %% [markdown]
# ### 5. Desnivel positivo acumulado en todo el año

# %%
# Total Climb in kms
df.Climb.sum()
# Out:
# 13413

# %% [markdown]
# ### 6. Extracción de datos y cálculos para evaluar la evolución

# %%
df.groupby('Month').agg({'Distance':'sum','Climb':['sum', 'max'], 'Avg_speed':['max','min']})
# Out:
#       Distance Climb      Avg_speed
#            sum   sum  max       max    min
# Month
# 1       143.92  1199  196     11.08  10.12
# 2       160.24  1244  167     11.30  10.04
# 3       146.19  1112   69     11.22  10.22
# 4       160.08  1054   91     11.55  10.44
# 5       163.83  1148   72     10.93  10.15
# 6         6.10    60   60      9.57   9.57
# 7       110.60  1270  122      9.28   7.57
# 8       148.14  1304  114     10.11   8.51
# 9       134.43  1575  220     10.45   8.56
# 10      161.88  1268   74     10.87  10.03
# 11      152.70  1170   87     10.96  10.17
# 12      102.46  1009  207     11.24   9.82

# %% [markdown]
# + Los máximos en Climb se corresponden con viajes a Luxemburgo, Francia y Valencia donde pude hacer rutas con mayor desnivel positivo que en la región en la que vivo.
# + De Julio a Septiembre se puede ver una evolución positiva y significativa en la velocidad promedio.
# + El mes con mayor acumulación de kms es mayo, tras 11 meses de entrenamiento continuo.
# + Junio pasó factura con una contractura que me obligó a descansar y sólo hacer bicicleta y caminata.
#
# ### Nos vemos el año próximo para comparar resultados y si nos cruzamos en alguna ruta... say *Hi!*
#
# ### Author: Anastasia Livio
